# %% [markdown]
# # Using RL Zoo Baseline3
#
#
# [`RL Baselines3 Zoo`](https://rl-baselines3-zoo.readthedocs.io/en/master/) is a training framework for Reinforcement Learning (RL), using Stable Baselines3 (SB3), reliable implementations of reinforcement learning algorithms in PyTorch. It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos. In addition, it includes a collection of tuned hyperparameters for common environments and RL algorithms, and agents trained with those settings.
#
# Github repository: https://github.com/DLR-RM/rl-baselines3-zoo
#
# In this notebook, we will train and record demos as well as push the trained agents to Huggingface - all using RL Zoo sb3.
#
# RL Zoo is supposed to be run from command line. However, we can use python notebooks to run commands using "!" bang character before the commands e.g., to run `pwd` unix command to list the current working directory, we can execute following command in a code cell `!pwd`.
#
# We have been using this to install the dependencies while running these notebooks in Google Colab e.g.
# ```
# !pip install "stable-baselines3[extra]
# ```

# %%
#!pip install rl_zoo3
# Out:
# Collecting rl_zoo3
#   Downloading rl_zoo3-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting sb3-contrib<3.0,>=2.3.0 (from rl_zoo3)
#   Downloading sb3_contrib-2.3.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: gymnasium~=0.29.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rl_zoo3) (0.29.1)
# Requirement already satisfied: huggingface-sb3<4.0,>=3.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rl_zoo3) (3.0)
# Requirement already satisfied: tqdm in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rl_zoo3) (4.66.1)
# Requirement already satisfied: rich in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rl_zoo3) (13.8.1)
# Collecting optuna>=3.0 (from rl_zoo3)
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rl_zoo3) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from gymnasium~=0.29.1->rl_zoo3) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from gymnasium~=0.29.1->rl_zoo3) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from gymnasium~=0.29.1->rl_zoo3) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from gymnasium~=0.29.1->rl_zoo3) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (0.25.0)
# Requirement already satisfied: wasabi in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from optuna>=3.0->rl_zoo3) (23.2)
# Collecting sqlalchemy>=1.3.0 (from optuna>=3.0->rl_zoo3)
#   Downloading SQLAlchemy-2.0.35-cp310-cp310-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from pytablewriter~=1.2->rl_zoo3) (68.1.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter~=1.2->rl_zoo3)
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3)
#   Downloading pathvalidate-3.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3)
#   Downloading tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3)
#   Downloading tcolorpy-0.1.6-py3-none-any.whl.metadata (6.4 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3)
#   Downloading typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting stable-baselines3<3.0,>=2.3.0 (from sb3-contrib<3.0,>=2.3.0->rl_zoo3)
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rich->rl_zoo3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from rich->rl_zoo3) (2.16.1)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: filelock in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2023.9.2)
# Requirement already satisfied: requests in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3) (0.1.2)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna>=3.0->rl_zoo3)
#   Downloading greenlet-3.1.1-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: torch>=1.13 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (2.1.0)
# Requirement already satisfied: pandas in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (2.2.2)
# Requirement already satisfied: matplotlib in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (3.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.16.0)
# Requirement already satisfied: sympy in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (1.12)
# Requirement already satisfied: networkx in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (3.2)
# Requirement already satisfied: jinja2 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (3.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (3.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from pandas->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.3.0->sb3-contrib<3.0,>=2.3.0->rl_zoo3) (1.3.0)
# Downloading rl_zoo3-2.3.0-py3-none-any.whl (76 kB)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
# Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
# Downloading sb3_contrib-2.3.0-py3-none-any.whl (80 kB)
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
# Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading pathvalidate-3.2.1-py3-none-any.whl (23 kB)
# Downloading SQLAlchemy-2.0.35-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 13.1 MB/s eta 0:00:00
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
# Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.6-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading greenlet-3.1.1-cp310-cp310-macosx_11_0_universal2.whl (271 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
# Installing collected packages: tcolorpy, pathvalidate, Mako, greenlet, colorlog, chardet, sqlalchemy, mbstrdecoder, typepy, stable-baselines3, alembic, sb3-contrib, optuna, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 2.1.0
#     Uninstalling stable-baselines3-2.1.0:
#       Successfully uninstalled stable-baselines3-2.1.0
# Successfully installed DataProperty-1.0.1 Mako-1.3.5 alembic-1.13.3 chardet-5.2.0 colorlog-6.8.2 greenlet-3.1.1 mbstrdecoder-1.1.3 optuna-4.0.0 pathvalidate-3.2.1 pytablewriter-1.2.0 rl_zoo3-2.3.0 sb3-contrib-2.3.0 sqlalchemy-2.0.35 stable-baselines3-2.3.2 tabledata-1.3.3 tcolorpy-0.1.6 typepy-1.3.2

# %% [markdown]
# #### Running in Colab/Kaggle
#
# If you are running this on Colab, please uncomment below cell and run this to install required dependencies.

# %%
## uncomment and execute this cell to install all the the dependencies if running in Google Colab or Kaggle
# !apt-get update 
# !apt-get install -y swig cmake ffmpeg freeglut3-dev xvfb

# %%
## Uncomment and execute this cell to install all the the dependencies if running in Google Colab or Kaggle

## Uncomment and run for Colab
# !git clone https://github.com/nsanghi/drl-2ed
# %cd /content/drl-2ed 
# !pip install  -r requirements.txt
# %cd chapter2


## Uncomment and run for Kaggle
# !git clone https://github.com/nsanghi/drl-2ed
# %cd /kaggle/working/drl-2ed 
# !pip install  -r requirements.txt
# %cd chapter2

# %% [markdown]
# ## Training LunarLander using DQN
#
# Same as the implementation we saw before - except this time done using RL Zoo
#
# Please note that the default parameters printed at the start of executing below command can be changed. You can refer to RL Zoo documentation for more details. Please also note that these default parameters are different form the the defaults while running the `model.train` from `stablebaseline3` - https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#stable_baselines3.dqn.DQN

# %%
# Train a DQN agent on LunarLander-v2

# !python -m rl_zoo3.train --algo dqn --env LunarLander-v2 --n-timesteps 100000 --log-interval 400 --progress
# Out:
# ========== LunarLander-v2 ==========
# Seed: 3737628595
# Loading hyperparameters from: /Users/ashis/venv-directory/venv-p310-RL-workspace/lib/python3.10/site-packages/rl_zoo3/hyperparams/dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 128),
#              ('buffer_size', 50000),
#              ('exploration_final_eps', 0.1),
#              ('exploration_fraction', 0.12),
#              ('gamma', 0.99),
#              ('gradient_steps', -1),
#              ('learning_rate', 0.00063),
#              ('learning_starts', 0),
#              ('n_timesteps', 100000.0),
#              ('policy', 'MlpPolicy'),
#              ('policy_kwargs', 'dict(net_arch=[256, 256])'),
#              ('target_update_interval', 250),
#              ('train_freq', 4)])
# Using 1 environments
# Overwriting n_timesteps with n=100000
# Creating test environment
# Using cpu device
# Log path: logs/dqn/LunarLander-v2_1
# Eval num_timesteps=25000, episode_reward=-55.24 +/- 49.76━━━━━━ 24,981/100,000  [ 0:01:22 < 0:04:37 , 271 it/s ]
# Episode length: 705.20 +/- 362.49━━━━━━━━━━━━━━━━━━ 24,981/100,000  [ 0:01:22 < 0:04:37 , 271 it/s ]
# ----------------------------------0m━━━━━━━━━━━━━━━━━━ 24,981/100,000  [ 0:01:22 < 0:04:37 , 271 it/s ]
# | eval/               |          |
# |    mean_ep_length   | 705      |
# |    mean_reward      | -55.2    |
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    total_timesteps  | 25000    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 1.06     |
# |    n_updates        | 24996    |
# ----------------------------------
# New best mean reward!━╺━━━━━━━━━━━━━━━━━━ 24,981/100,000  [ 0:01:22 < 0:04:37 , 271 it/s ]
# Eval num_timesteps=50000, episode_reward=218.29 +/- 45.66━━━━━━ 49,977/100,000  [ 0:02:55 < 0:03:04 , 272 it/s ]
# Episode length: 626.20 +/- 307.54╺━━━━━━━━━━━━ 49,977/100,000  [ 0:02:55 < 0:03:04 , 272 it/s ]
# ----------------------------------90m╺━━━━━━━━━━━━ 49,977/100,000  [ 0:02:55 < 0:03:04 , 272 it/s ]
# | eval/               |          |
# |    mean_ep_length   | 626      |
# |    mean_reward      | 218      |
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    total_timesteps  | 50000    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 2.29     |
# |    n_updates        | 49996    |
# ----------------------------------
# New best mean reward!━━━━━━━╺━━━━━━━━━━━━ 49,977/100,000  [ 0:02:55 < 0:03:04 , 272 it/s ]
# Eval num_timesteps=75000, episode_reward=24.15 +/- 83.29m━━━━━━ 74,991/100,000  [ 0:04:29 < 0:01:40 , 251 it/s ]
# Episode length: 904.80 +/- 190.40━╸━━━━━━ 74,991/100,000  [ 0:04:29 < 0:01:40 , 251 it/s ]
# ----------------------------------╸━━━━━━ 74,991/100,000  [ 0:04:29 < 0:01:40 , 251 it/s ]
# | eval/               |          |
# |    mean_ep_length   | 905      |
# |    mean_reward      | 24.1     |
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    total_timesteps  | 75000    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.377    |
# |    n_updates        | 74996    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-66.72 +/- 225.0899,996/100,000  [ 0:06:05 < 0:00:01 , 303 it/s ]t/s ]
# Episode length: 127.80 +/- 25.70━━━━━━━━╸ 99,996/100,000  [ 0:06:05 < 0:00:01 , 303 it/s ]
# ----------------------------------━━━━━━╸ 99,996/100,000  [ 0:06:05 < 0:00:01 , 303 it/s ]
# | eval/               |          |
# |    mean_ep_length   | 128      |
# |    mean_reward      | -66.7    |
# | rollout/            |          |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.529    |
# |    n_updates        | 99996    |
# ----------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━ 100,000/100,000  [ 0:06:05 < 0:00:00 , 300 it/s ] ]
# Saving to logs/dqn/LunarLander-v2_1

# %% [markdown]
# ## Evaluting the agent
#
# We will now evaluate the above trained agent by loading the best model saved by above command.

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env LunarLander-v2 --no-render --n-timesteps 5000 --folder logs/
# Out:
# Loading latest experiment, id=1
# Loading logs/dqn/LunarLander-v2_1/LunarLander-v2.zip
# Episode Reward: 46.67
# Episode Length 96
# Episode Reward: 48.81
# Episode Length 98
# Episode Reward: -3.00
# Episode Length 107
# Episode Reward: 10.32
# Episode Length 100
# Episode Reward: 238.38
# Episode Length 155
# Episode Reward: 237.41
# Episode Length 327
# Episode Reward: 4.81
# Episode Length 97
# Episode Reward: -65.38
# Episode Length 93
# Episode Reward: -431.50
# Episode Length 328
# Episode Reward: 220.13
# Episode Length 281
# Episode Reward: 230.98
# Episode Length 433
# Episode Reward: 53.84
# Episode Length 92
# Episode Reward: -297.33
# Episode Length 453
# Episode Reward: -475.07
# Episode Length 726
# Episode Reward: 28.07
# Episode Length 94
# Episode Reward: -154.49
# Episode Length 159
# Episode Reward: -341.21
# Episode Length 134
# Episode Reward: 28.65
# Episode Length 97
# Episode Reward: 3.44
# Episode Length 122
# Episode Reward: -475.18
# Episode Length 779
# Episode Reward: -2.28
# Episode Length 99
# 21 Episodes
# Mean reward: -52.09 +/- 222.31
# Mean episode length: 231.90 +/- 203.27

# %% [markdown]
# ## Recordig a video
#
# Let us now record a video of trained agent

# %%
# !python -m rl_zoo3.record_video --algo dqn --env LunarLander-v2 --exp-id 0 -f logs/ -n 1000
# Out:
# Loading latest experiment, id=1
# Loading logs/dqn/LunarLander-v2_1/LunarLander-v2.zip
# Loading logs/dqn/LunarLander-v2_1/LunarLander-v2.zip
# Saving video to /Users/ashis/Documents/Teaching/Reinforcement-Learning/Lectures/2024-lectures/drl-ashiskb/logs/dqn/LunarLander-v2_1/videos/final-model-dqn-LunarLander-v2-step-0-to-step-1000.mp4
# Moviepy - Building video /Users/ashis/Documents/Teaching/Reinforcement-Learning/Lectures/2024-lectures/drl-ashiskb/logs/dqn/LunarLander-v2_1/videos/final-model-dqn-LunarLander-v2-step-0-to-step-1000.mp4.
# Moviepy - Writing video /Users/ashis/Documents/Teaching/Reinforcement-Learning/Lectures/2024-lectures/drl-ashiskb/logs/dqn/LunarLander-v2_1/videos/final-model-dqn-LunarLander-v2-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /Users/ashis/Documents/Teaching/Reinforcement-Learning/Lectures/2024-lectures/drl-ashiskb/logs/dqn/LunarLander-v2_1/videos/final-model-dqn-LunarLander-v2-step-0-to-step-1000.mp4

# %% [markdown]
# ## Display the video

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay


def show_videos(video_path="", prefix=""):
    """
    Taken from https://github.com/eleurent/highway-env

    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) Filter the video, showing only the only starting with this prefix
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
show_videos(video_path='logs/dqn/LunarLander-v2_1/videos/', prefix='')
# Out:
# <video alt="logs/dqn/LunarLander-v2_1/videos/final-model-dqn-LunarLander-v2-step-0-to-step-1000.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Pushing to Huggingface
#
# To share with others, you can push the trained model to huggingface. First we need to login into hugginfcae using the token

# %%
from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import login # To log to our Hugging Face account to be able to upload models to the Hub.

login()
#!git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# **IMPORTANT**
# Some users have reported facing following error while running `rl_zoo3.push_to_hub` .
#
# ```
# "Token is required (write-access action) but no token found. You need to provide a token or be logged in to Hugging Face with `huggingface-cli login` or `huggingface_hub.login`. See https://huggingface.co/settings/tokens."
# ```
#
# In such a case the following command will help you over come the issue
#
# ```
# import huggingface_hub
#
# huggingface_hub.login(token= <YOUR_HF_TOKEN>,
#                      write_permission = True,
#                     add_to_git_credential = True)
#
# ```
#
# Another alternative is to use following command from command shell where the `venv` or `conda` environment for this repository has been activated and then follow the instructions to set the HuggingFace token.
#
# ```
# huggingface-cli login
#
# ```

# %%
# Before you run this, change -orga to your huggingface id

# !python -m rl_zoo3.push_to_hub --algo dqn --env LunarLander-v2 -f logs/ -orga ashiskb -m "Initial commit"

# %% [markdown]
# ## See model at Huggingface Hub
#
# Click on link below to see the stored trained agent and video on huggingface
#
# https://huggingface.co/ashiskb/dqn-LunarLander-v2
#
# In your case it would look like
#
# `https://huggingface.co/<orga>/<algo>-<env>`
